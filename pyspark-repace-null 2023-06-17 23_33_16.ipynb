# %%
import os
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[1]") \
    .appName("SparkByExamples.com") \
    .getOrCreate()

# %%
current_dir = os.path.dirname(os.path.abspath(__file__))
filePath = os.path.join(current_dir, "small_zipcode.csv")

df = spark.read.options(header='true', inferSchema='true') \
          .csv(filePath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4257216822594873>:1
# ----> 1 current_dir = os.path.dirname(os.path.abspath(__file__))
#       2 filePath = os.path.join(current_dir, "small_zipcode.csv")
#       4 df = spark.read.options(header='true', inferSchema='true') \
#       5           .csv(filePath)
#
# NameError: name '__file__' is not defined

# %%
df.printSchema()
df.show(truncate=False)


df.fillna(value=0).show()
df.fillna(value=0,subset=["population"]).show()
df.na.fill(value=0).show()
df.na.fill(value=0,subset=["population"]).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4257216822594875>:1
# ----> 1 df.printSchema()
#       2 df.show(truncate=False)
#       5 df.fillna(value=0).show()
#
# NameError: name 'df' is not defined

# %%
df.fillna(value="").show()
df.na.fill(value="").show()

df.fillna("unknown",["city"]) \
    .fillna("",["type"]).show()

df.fillna({"city": "unknown", "type": ""}) \
    .show()

df.na.fill("unknown",["city"]) \
    .na.fill("",["type"]).show()

df.na.fill({"city": "unknown", "type": ""}) \
    .show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4257216822594876>:1
# ----> 1 df.fillna(value="").show()
#       2 df.na.fill(value="").show()
#       4 df.fillna("unknown",["city"]) \
#       5     .fillna("",["type"]).show()
#
# NameError: name 'df' is not defined
